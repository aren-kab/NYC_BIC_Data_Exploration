# %%
#install packages
import numpy as np
import pandas as pd
import seaborn as sns

#load data
complaints_inquiries= pd.read_csv('/Users/aren_kab/Documents/Job Search/BIC Data Analyst /explorationdatasets/BIC_Complaints_Inquiries.csv', parse_dates=['DATE COMPLAINT/INQUIRY REPORTED ON'])

# %%
complaints_inquiries.head()
# Out:
#   COMPLAINT/INQUIRY NUMBER LICENSE TYPE                ACCOUNT NAME  \
# 0              COMP-193716          NaN                         NaN
# 1               2010-00210          NaN                         NaN
# 2               2008-00382          NaN                         NaN
# 3               2009-01226          NaN  T. I. A. OF NEW  YORK INC.
# 4               2008-01530          NaN                         NaN
#
#   BIC NUMBER DATE COMPLAINT/INQUIRY REPORTED ON INDUSTRY TYPE ACCOUNT STATUS  \
# 0        NaN                         2017-10-26   Trade Waste            NaN
# 1    TWC-NaN                                NaT   Trade Waste            NaN
# 2   TWC-1059                                NaT   Trade Waste            NaN
# 3   TWC-1157                                NaT   Trade Waste            NaN
# 4      TWC-0                                NaT   Trade Waste            NaN
#
#   SOURCE OF COMPLAINT/INQUIRY COMPLAINT/INQUIRY DISPOSITION  \
# 0                        MAIL    Referred to Another Agency
# 1                PHONE - 6300         Referred To BIC Legal
# 2            311/PHONE - 9278                      Resolved
# 3            311/PHONE - 9278                      Resolved
# 4                        MAIL             Violation Written
#
#   COMPLAINT/INQUIRY STATUS  ...  EXPORT DATE Borough Latitude Longitide  \
# 0                   Closed  ...   2022-12-12     NaN      NaN       NaN
# 1                   Closed  ...   2022-12-12     NaN      NaN       NaN
# 2                   Closed  ...   2022-12-12     NaN      NaN       NaN
# 3                   Closed  ...   2022-12-12     NaN      NaN       NaN
# 4                   Closed  ...   2022-12-12     NaN      NaN       NaN
#
#   Community Board Council District Census Tract BIN BBL  NTA
# 0             NaN              NaN          NaN NaN NaN  NaN
# 1             NaN              NaN          NaN NaN NaN  NaN
# 2             NaN              NaN          NaN NaN NaN  NaN
# 3             NaN              NaN          NaN NaN NaN  NaN
# 4             NaN              NaN          NaN NaN NaN  NaN
#
# [5 rows x 42 columns]

# %%
#basic info
complaints_inquiries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17800 entries, 0 to 17799
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   COMPLAINT/INQUIRY NUMBER            17800 non-null  object
#  1   LICENSE TYPE                        2126 non-null   object
#  2   ACCOUNT NAME                        5088 non-null   object
#  3   BIC NUMBER                          12255 non-null  object
#  4   DATE COMPLAINT/INQUIRY REPORTED ON  5978 non-null   datetime64[ns]
#  5   INDUSTRY TYPE                       17800 non-null  object
#  6   ACCOUNT STATUS                      2454 non-null   object
#  7   SOURCE OF COMPLAINT/INQUIRY         17788 non-null  object
#  8   COMPLAINT/INQUIRY DISPOSITION       17141 non-null  object
#  9   COMPLAINT/INQUIRY STATUS            17670 non-null  object
#  10  TOTAL RESPONSE TIME                 5934 non-null   float64
#  11  COMPLAINT OR INQUIRY                17800 non-null  object
#  12  NATURE OF COMPLAINT/INQUIRY         17422 non-null  object
#  13  COMPLAINT/INQUIRY STREET ADDRESS    6341 non-null   object
#  14  COMPLAINT/INQUIRY CITY              5728 non-null   object
#  15  COMPLAINT/INQUIRY STATE             9088 non-null   object
#  16  COMPLAINT/INQUIRY ZIP               2812 non-null   object
#  17  COMPLAINT/INQUIRY BOROUGH           5469 non-null   object
#  18  ACCOUNT FOCUS OF COMPLAINT/INQUIRY  6055 non-null   object
#  19  ACCOUNT ADDRESS                     5947 non-null   object
#  20  ACCOUNT CITY                        5935 non-null   object
#  21  ACCOUNT STATE                       6206 non-null   object
#  22  ACCOUNT ZIP                         3931 non-null   object
#  23  ACCOUNT PHONE                       3174 non-null   object
#  24  VEHICLE MAKE                        26 non-null     object
#  25  VEHICLE MODEL                       19 non-null     object
#  26  VEHICLE TYPE                        25 non-null     object
#  27  VEHICLE YEAR                        22 non-null     float64
#  28  VEHICLE COLOR                       21 non-null     object
#  29  CONTACTED COMPLAINANT               17800 non-null  bool
#  30  UNABLE TO CONTACT COMPLAINANT       17800 non-null  bool
#  31  METHOD USED TO CONTACT COMPLAINANT  4548 non-null   object
#  32  EXPORT DATE                         17800 non-null  object
#  33  Borough                             2215 non-null   object
#  34  Latitude                            2215 non-null   float64
#  35  Longitide                           2215 non-null   float64
#  36  Community Board                     2215 non-null   float64
#  37  Council District                    2215 non-null   float64
#  38  Census Tract                        2215 non-null   float64
#  39  BIN                                 2169 non-null   float64
#  40  BBL                                 2169 non-null   float64
#  41  NTA                                 2215 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(9), object(30)
# memory usage: 5.5+ MB

# %%
#summerize table
complaints_inquiries.describe()
# Out:
#        TOTAL RESPONSE TIME  VEHICLE YEAR     Latitude    Longitide  \
# count          5934.000000     22.000000  2215.000000  2215.000000
# mean              3.599933   2008.409091    40.717668   -73.934126
# std              12.141854      7.829487     0.075642     0.085804
# min             -12.000000   1995.000000    40.504310   -74.248905
# 25%               0.000000   2002.000000    40.672087   -73.987604
# 50%               1.000000   2007.500000    40.724531   -73.946977
# 75%               4.000000   2016.000000    40.761655   -73.882347
# max             539.000000   2020.000000    40.908233   -73.706590
#
#        Community Board  Council District   Census Tract           BIN  \
# count      2215.000000       2215.000000    2215.000000  2.169000e+03
# mean          6.846501         23.660948    6591.396388  2.826592e+06
# std           5.420769         15.878837   21603.565875  1.344248e+06
# min           1.000000          1.000000       1.000000  1.000000e+06
# 25%           3.000000          7.000000      99.000000  1.081179e+06
# 50%           6.000000         25.000000     284.000000  3.095946e+06
# 75%          10.000000         37.000000     751.500000  4.061724e+06
# max          83.000000         51.000000  157903.000000  5.163345e+06
#
#                 BBL
# count  2.169000e+03
# mean   2.744639e+09
# std    1.301213e+09
# min    1.000078e+09
# 25%    1.016610e+09
# 50%    3.029200e+09
# 75%    4.018470e+09
# max    5.080420e+09

# %% [markdown]
# ### Getting Started Questions
# #### What percent of complaints came through 311 in a certain period of time?
# #### What was the average total response time of complaints in a certain period of time?
# #### What are the top three sources of an inquiry?

# %%
#Getting Started Questions to familiarize with data- Keep rows neccessary 
complaints_inquiries_gs = complaints_inquiries.iloc[:, [1, 2,4,7,10,31,32,33]]
complaints_inquiries_gs.head()
# Out:
#   LICENSE TYPE                ACCOUNT NAME DATE COMPLAINT/INQUIRY REPORTED ON  \
# 0          NaN                         NaN                         2017-10-26
# 1          NaN                         NaN                                NaT
# 2          NaN                         NaN                                NaT
# 3          NaN  T. I. A. OF NEW  YORK INC.                                NaT
# 4          NaN                         NaN                                NaT
#
#   SOURCE OF COMPLAINT/INQUIRY  TOTAL RESPONSE TIME  \
# 0                        MAIL                  0.0
# 1                PHONE - 6300                  NaN
# 2            311/PHONE - 9278                  NaN
# 3            311/PHONE - 9278                  NaN
# 4                        MAIL                  NaN
#
#   METHOD USED TO CONTACT COMPLAINANT EXPORT DATE Borough
# 0                             Letter  2022-12-12     NaN
# 1                                NaN  2022-12-12     NaN
# 2                                NaN  2022-12-12     NaN
# 3                                NaN  2022-12-12     NaN
# 4                                NaN  2022-12-12     NaN

# %%
complaints_inquiries_gs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17800 entries, 0 to 17799
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   LICENSE TYPE                        2126 non-null   object
#  1   ACCOUNT NAME                        5088 non-null   object
#  2   DATE COMPLAINT/INQUIRY REPORTED ON  5978 non-null   datetime64[ns]
#  3   SOURCE OF COMPLAINT/INQUIRY         17788 non-null  object
#  4   TOTAL RESPONSE TIME                 5934 non-null   float64
#  5   METHOD USED TO CONTACT COMPLAINANT  4548 non-null   object
#  6   EXPORT DATE                         17800 non-null  object
#  7   Borough                             2215 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 1.1+ MB

# %%
#Check the date range - 
print(complaints_inquiries_gs['DATE COMPLAINT/INQUIRY REPORTED ON'].max())
print(complaints_inquiries_gs['DATE COMPLAINT/INQUIRY REPORTED ON'].min())
# Out:
# 2022-12-08 00:00:00
# 2006-10-16 00:00:00

# %%
#lets use 2019 -2021 data to get a clean 3 years
complaints19_21 = complaints_inquiries_gs.loc[(complaints_inquiries_gs['DATE COMPLAINT/INQUIRY REPORTED ON'] >= '2019-01-01')
                     & (complaints_inquiries_gs['DATE COMPLAINT/INQUIRY REPORTED ON'] < '2022-01-01')]

# %%
# Let's look at the number of complaints sources for the top 5
import matplotlib.pyplot as plt
complaints19_21['SOURCE OF COMPLAINT/INQUIRY'].value_counts().head().plot(kind='bar', color = 'navy')
plt.xlabel("Source of Complaint")
plt.ylabel("Total Count of complaints 19'-21'")
# Out:
# Text(0, 0.5, "Total Count of complaints 19'-21'")

# %% [markdown]
# #### Q3: The top 3 sources of an inquiry are Web-Mail, Phone, and E-mail

# %%
#FOR THE PAST Three years Value for 311
Percent_311= (len(complaints19_21[complaints19_21['SOURCE OF COMPLAINT/INQUIRY']=='311/PHONE - 9278'])/complaints19_21['SOURCE OF COMPLAINT/INQUIRY'].count()*100)

# %%
print('Q1:',Percent_311.round(2), "% of complaints came through 311 from 2019-2021")
# Out:
# Q1: 6.89 % of complaints came through 311 from 2019-2021

# %%
#Let's Solve for avg response time
complaints19_21.head(2)
# Out:
#                     LICENSE TYPE                         ACCOUNT NAME  \
# 19                           NaN                                  NaN
# 29  Trade Waste;Transfer Station  WASTE CONNECTIONS OF NEW YORK, INC.
#
#    DATE COMPLAINT/INQUIRY REPORTED ON SOURCE OF COMPLAINT/INQUIRY  \
# 19                         2021-09-30                    WEB-MAIL
# 29                         2020-07-02                PHONE - 6300
#
#     TOTAL RESPONSE TIME METHOD USED TO CONTACT COMPLAINANT EXPORT DATE  \
# 19                  0.0                         Phone Call  2022-12-12
# 29                  4.0                         Phone Call  2022-12-12
#
#       Borough
# 19        NaN
# 29  MANHATTAN

# %%
Average_Response_Time_19_21 = (sum(complaints19_21['TOTAL RESPONSE TIME'])/len(complaints19_21['TOTAL RESPONSE TIME']))

# %%
format(Average_Response_Time_19_21,'.2f')
# Out:
# '3.74'

# %%
print('Q2: Average Response time was', format(Average_Response_Time_19_21,'.2f'),'days for complaints between 2019-2021')
# Out:
# Q2: Average Response time was 3.74 days for complaints between 2019-2021

# %% [markdown]
# ## Getting Started Questions
# #### Q1: 6.89 % of complaints came through 311 from 2019-2021
# #### Q2: Average Response time was 3.74 days for complaints between 2019-2021
# #### Q3: The top 3 sources of an inquiry are Web-Mail, Phone, and E-mail

# %% [markdown]
# ## Unique Analysis

# %% [markdown]
# ### With the recent pandemic, and the data available I'm interested here to see if the complaint nature and complaint geography has changed. To do so I'll work through the following exericizes

# %% [markdown]
# ### Create two distinct datasets, one before the pandemic (March 2017 - Nov 2019) for the same time period of time to try to mimic behavior as much as possible (March 2020- Nov- 2022).
#
# #### *A caveat here is there are many varib\ales that cause this to not be a true 1:1 Comparasion including the recent "new normal of the pandemic"

# %%
complaints_inquiries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17800 entries, 0 to 17799
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   COMPLAINT/INQUIRY NUMBER            17800 non-null  object
#  1   LICENSE TYPE                        2126 non-null   object
#  2   ACCOUNT NAME                        5088 non-null   object
#  3   BIC NUMBER                          12255 non-null  object
#  4   DATE COMPLAINT/INQUIRY REPORTED ON  5978 non-null   datetime64[ns]
#  5   INDUSTRY TYPE                       17800 non-null  object
#  6   ACCOUNT STATUS                      2454 non-null   object
#  7   SOURCE OF COMPLAINT/INQUIRY         17788 non-null  object
#  8   COMPLAINT/INQUIRY DISPOSITION       17141 non-null  object
#  9   COMPLAINT/INQUIRY STATUS            17670 non-null  object
#  10  TOTAL RESPONSE TIME                 5934 non-null   float64
#  11  COMPLAINT OR INQUIRY                17800 non-null  object
#  12  NATURE OF COMPLAINT/INQUIRY         17422 non-null  object
#  13  COMPLAINT/INQUIRY STREET ADDRESS    6341 non-null   object
#  14  COMPLAINT/INQUIRY CITY              5728 non-null   object
#  15  COMPLAINT/INQUIRY STATE             9088 non-null   object
#  16  COMPLAINT/INQUIRY ZIP               2812 non-null   object
#  17  COMPLAINT/INQUIRY BOROUGH           5469 non-null   object
#  18  ACCOUNT FOCUS OF COMPLAINT/INQUIRY  6055 non-null   object
#  19  ACCOUNT ADDRESS                     5947 non-null   object
#  20  ACCOUNT CITY                        5935 non-null   object
#  21  ACCOUNT STATE                       6206 non-null   object
#  22  ACCOUNT ZIP                         3931 non-null   object
#  23  ACCOUNT PHONE                       3174 non-null   object
#  24  VEHICLE MAKE                        26 non-null     object
#  25  VEHICLE MODEL                       19 non-null     object
#  26  VEHICLE TYPE                        25 non-null     object
#  27  VEHICLE YEAR                        22 non-null     float64
#  28  VEHICLE COLOR                       21 non-null     object
#  29  CONTACTED COMPLAINANT               17800 non-null  bool
#  30  UNABLE TO CONTACT COMPLAINANT       17800 non-null  bool
#  31  METHOD USED TO CONTACT COMPLAINANT  4548 non-null   object
#  32  EXPORT DATE                         17800 non-null  object
#  33  Borough                             2215 non-null   object
#  34  Latitude                            2215 non-null   float64
#  35  Longitide                           2215 non-null   float64
#  36  Community Board                     2215 non-null   float64
#  37  Council District                    2215 non-null   float64
#  38  Census Tract                        2215 non-null   float64
#  39  BIN                                 2169 non-null   float64
#  40  BBL                                 2169 non-null   float64
#  41  NTA                                 2215 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(9), object(30)
# memory usage: 5.5+ MB

# %%
#get required cells
complaints_inquiries_ua = complaints_inquiries.iloc[:, [0,1, 2,4,5,12,14,33,34,35]]
complaints_inquiries_ua
# Out:
#       COMPLAINT/INQUIRY NUMBER LICENSE TYPE                      ACCOUNT NAME  \
# 0                  COMP-193716          NaN                               NaN
# 1                   2010-00210          NaN                               NaN
# 2                   2008-00382          NaN                               NaN
# 3                   2009-01226          NaN        T. I. A. OF NEW  YORK INC.
# 4                   2008-01530          NaN                               NaN
# ...                        ...          ...                               ...
# 17795              COMP-195415  Trade Waste  CITYWIDE CONTAINER SERVICE CORP.
# 17796              COMP-191112          NaN                               NaN
# 17797               2009-01825          NaN                               NaN
# 17798               2012-00639          NaN                       225 OAK LLC
# 17799               2011-00338          NaN                               NaN
#
#       DATE COMPLAINT/INQUIRY REPORTED ON INDUSTRY TYPE  \
# 0                             2017-10-26   Trade Waste
# 1                                    NaT   Trade Waste
# 2                                    NaT   Trade Waste
# 3                                    NaT   Trade Waste
# 4                                    NaT   Trade Waste
# ...                                  ...           ...
# 17795                         2020-04-08   Trade Waste
# 17796                         2014-09-15   Trade Waste
# 17797                                NaT   Trade Waste
# 17798                                NaT   Trade Waste
# 17799                                NaT   Trade Waste
#
#                        NATURE OF COMPLAINT/INQUIRY COMPLAINT/INQUIRY CITY  \
# 0                             Misinformation - All                  Alden
# 1                                Information - All                    NaN
# 2                          Recycling - Trade Waste                    NaN
# 3      Service - All;Cardboard-Other - Trade Waste                    NaN
# 4                  Unlicensed Carter - Trade Waste                    NaN
# ...                                            ...                    ...
# 17795           Containers-Unremoved - Trade Waste               Brooklyn
# 17796                                Service - All                    NaN
# 17797                            Information - All                UNKNOWN
# 17798  Other - All;Unlicensed Broker - Trade Waste                    NaN
# 17799                            Information - All              Manhattan
#
#          Borough   Latitude  Longitide
# 0            NaN        NaN        NaN
# 1            NaN        NaN        NaN
# 2            NaN        NaN        NaN
# 3            NaN        NaN        NaN
# 4            NaN        NaN        NaN
# ...          ...        ...        ...
# 17795   BROOKLYN  40.684187 -73.879764
# 17796        NaN        NaN        NaN
# 17797        NaN        NaN        NaN
# 17798        NaN        NaN        NaN
# 17799  MANHATTAN  40.839760 -73.940705
#
# [17800 rows x 10 columns]

# %%
#setup_geopandas
import geopandas

path_to_data = geopandas.datasets.get_path("nybb")
gdf = geopandas.read_file(path_to_data)

gdf
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330470.010332  1.623820e+09
# 1         4         Queens  896344.047763  3.045213e+09
# 2         3       Brooklyn  741080.523166  1.937479e+09
# 3         1      Manhattan  359299.096471  6.364715e+08
# 4         2          Bronx  464392.991824  1.186925e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 2  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %%
#Dataset 1 with time range pre-pandemic 
#(March 2017 - Nov 2019) for the same time period of time beforeto try to mimic behavior as much as possible 
complaints_pre_covid = complaints_inquiries_ua.loc[(complaints_inquiries_ua['DATE COMPLAINT/INQUIRY REPORTED ON'] >= '2017-03-01')
                     & (complaints_inquiries_ua['DATE COMPLAINT/INQUIRY REPORTED ON'] < '2019-12-01')]

# %%
complaints_pre_covid.head()
# Out:
#    COMPLAINT/INQUIRY NUMBER LICENSE TYPE             ACCOUNT NAME  \
# 0               COMP-193716          NaN                      NaN
# 38               INQ-193496          NaN                      NaN
# 42               INQ-193821          NaN                      NaN
# 46              COMP-195079  Trade Waste  D & D CARTING CO., INC.
# 52               INQ-194679          NaN                      NaN
#
#    DATE COMPLAINT/INQUIRY REPORTED ON INDUSTRY TYPE  \
# 0                          2017-10-26   Trade Waste
# 38                         2017-05-30   Trade Waste
# 42                         2018-01-10   Trade Waste
# 46                         2019-08-23   Trade Waste
# 52                         2019-01-28   Trade Waste
#
#           NATURE OF COMPLAINT/INQUIRY COMPLAINT/INQUIRY CITY Borough  \
# 0                Misinformation - All                  Alden     NaN
# 38               Misinformation - All                    NaN     NaN
# 42                  Information - All                    NaN     NaN
# 46         Other - All;Criminal - All                    NaN     NaN
# 52  Information - All;Licensing - All                    NaN     NaN
#
#     Latitude  Longitide
# 0        NaN        NaN
# 38       NaN        NaN
# 42       NaN        NaN
# 46       NaN        NaN
# 52       NaN        NaN

# %%
complaints_post_covid = complaints_inquiries_ua.loc[(complaints_inquiries_ua['DATE COMPLAINT/INQUIRY REPORTED ON'] >= '2020-03-01')
                     & (complaints_inquiries_ua['DATE COMPLAINT/INQUIRY REPORTED ON'] < '2022-12-01')]

# %%
complaints_post_covid.head()
# Out:
#    COMPLAINT/INQUIRY NUMBER                  LICENSE TYPE  \
# 19              COMP-196188                           NaN
# 29              COMP-195525  Trade Waste;Transfer Station
# 36              COMP-195667                   Trade Waste
# 49              COMP-196639                           NaN
# 62              COMP-196364                   Trade Waste
#
#                            ACCOUNT NAME DATE COMPLAINT/INQUIRY REPORTED ON  \
# 19                                  NaN                         2021-09-30
# 29  WASTE CONNECTIONS OF NEW YORK, INC.                         2020-07-02
# 36          D. DANIELS CONTRACTING LTD.                         2020-09-23
# 49                                  NaN                         2022-09-02
# 62              FALSO CARTING CO., INC.                         2022-03-02
#
#    INDUSTRY TYPE             NATURE OF COMPLAINT/INQUIRY  \
# 19   Trade Waste                             Other - All
# 29   Trade Waste                           Service - All
# 36   Trade Waste                           Service - All
# 49   Trade Waste  Quality of Life-Spillage - Trade Waste
# 62   Trade Waste            Unsafe Driving - Trade Waste
#
#    COMPLAINT/INQUIRY CITY    Borough   Latitude  Longitide
# 19                    NaN        NaN        NaN        NaN
# 29               New York  MANHATTAN  40.719852 -73.998683
# 36                 Queens        NaN        NaN        NaN
# 49               Brooklyn        NaN        NaN        NaN
# 62                  Bronx        NaN        NaN        NaN

# %% [markdown]
# #### Answer The following questions:
# ##### 1. What is the timeline of complaints of the two periods?
# ##### 2. What are the top 5 nature of complaints/inquiries in each period?
# ##### 3. What is the geographic distribution of violations by city?

# %% [markdown]
# ##### 1. What is the timeline of complaints of the two periods?

# %%
complaints_pre_covid['Month-Year of Complaint/Inquiry']=complaints_pre_covid['DATE COMPLAINT/INQUIRY REPORTED ON'].dt.to_period('M')
# Out:
# /var/folders/vp/2flcfxx12ns473tz77qt51v80000gn/T/ipykernel_10933/1362881641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints_pre_covid['Month-Year of Complaint/Inquiry']=complaints_pre_covid['DATE COMPLAINT/INQUIRY REPORTED ON'].dt.to_period('M')

# %%
complaints_post_covid['Month-Year of Complaint/Inquiry']=complaints_post_covid['DATE COMPLAINT/INQUIRY REPORTED ON'].dt.to_period('M')
# Out:
# /var/folders/vp/2flcfxx12ns473tz77qt51v80000gn/T/ipykernel_10933/2125920271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complaints_post_covid['Month-Year of Complaint/Inquiry']=complaints_post_covid['DATE COMPLAINT/INQUIRY REPORTED ON'].dt.to_period('M')

# %%
complaints_pre_covid
# Out:
#       COMPLAINT/INQUIRY NUMBER LICENSE TYPE                  ACCOUNT NAME  \
# 0                  COMP-193716          NaN                           NaN
# 38                  INQ-193496          NaN                           NaN
# 42                  INQ-193821          NaN                           NaN
# 46                 COMP-195079  Trade Waste       D & D CARTING CO., INC.
# 52                  INQ-194679          NaN                           NaN
# ...                        ...          ...                           ...
# 17690              COMP-194033  Trade Waste       FIVE STAR CARTING, INC.
# 17720              COMP-194844  Trade Waste  QUALITY WASTE SERVICES CORP.
# 17760              COMP-194259          NaN                           NaN
# 17781              COMP-194139  Trade Waste   D. DANIELS CONTRACTING LTD.
# 17783               INQ-194459          NaN                           NaN
#
#       DATE COMPLAINT/INQUIRY REPORTED ON INDUSTRY TYPE  \
# 0                             2017-10-26   Trade Waste
# 38                            2017-05-30   Trade Waste
# 42                            2018-01-10   Trade Waste
# 46                            2019-08-23   Trade Waste
# 52                            2019-01-28   Trade Waste
# ...                                  ...           ...
# 17690                         2018-04-19   Trade Waste
# 17720                         2019-05-02   Trade Waste
# 17760                         2018-08-16   Trade Waste
# 17781                         2018-06-18   Trade Waste
# 17783                         2018-11-07   Trade Waste
#
#                             NATURE OF COMPLAINT/INQUIRY  \
# 0                                  Misinformation - All
# 38                                 Misinformation - All
# 42                                    Information - All
# 46                           Other - All;Criminal - All
# 52                    Information - All;Licensing - All
# ...                                                 ...
# 17690                    Change of Carter - Trade Waste
# 17720               Quality of Life-Noise - Trade Waste
# 17760                   Unlicensed Carter - Trade Waste
# 17781  Quality of Life-Odor - Trade Waste;Service - All
# 17783                                   Licensing - All
#
#       COMPLAINT/INQUIRY CITY   Borough   Latitude  Longitide  \
# 0                      Alden       NaN        NaN        NaN
# 38                       NaN       NaN        NaN        NaN
# 42                       NaN       NaN        NaN        NaN
# 46                       NaN       NaN        NaN        NaN
# 52                       NaN       NaN        NaN        NaN
# ...                      ...       ...        ...        ...
# 17690               Brooklyn  BROOKLYN  40.619263 -73.982991
# 17720                    NaN       NaN        NaN        NaN
# 17760               New York       NaN        NaN        NaN
# 17781                Jamaica       NaN        NaN        NaN
# 17783                    NaN       NaN        NaN        NaN
#
#       Month-Year of Complaint/Inquiry
# 0                             2017-10
# 38                            2017-05
# 42                            2018-01
# 46                            2019-08
# 52                            2019-01
# ...                               ...
# 17690                         2018-04
# 17720                         2019-05
# 17760                         2018-08
# 17781                         2018-06
# 17783                         2018-11
#
# [1535 rows x 11 columns]

# %%
pre_covid_dates = complaints_pre_covid['Month-Year of Complaint/Inquiry'].value_counts().sort_index().to_frame()

# %%
post_covid_dates = complaints_post_covid['Month-Year of Complaint/Inquiry'].value_counts().sort_index().to_frame()

# %%
post_covid_dates
# Out:
#          Month-Year of Complaint/Inquiry
# 2020-03                               58
# 2020-04                               41
# 2020-05                               28
# 2020-06                               30
# 2020-07                               52
# 2020-08                               54
# 2020-09                               37
# 2020-10                               39
# 2020-11                               26
# 2020-12                               28
# 2021-01                               25
# 2021-02                               15
# 2021-03                               33
# 2021-04                               50
# 2021-05                               54
# 2021-06                               38
# 2021-07                               43
# 2021-08                               42
# 2021-09                               39
# 2021-10                               31
# 2021-11                               32
# 2021-12                               22
# 2022-01                               21
# 2022-02                               24
# 2022-03                               20
# 2022-04                               29
# 2022-05                               31
# 2022-06                               25
# 2022-07                               32
# 2022-08                               33
# 2022-09                               31
# 2022-10                               21
# 2022-11                               24

# %%
fig, axes = plt.subplots(nrows=2, ncols=1,figsize =(11,11))    
plt.subplots_adjust(wspace=1, hspace=.3)
pre_covid_dates.plot(ax=axes[0], title='Pre-Covid Complaints', xlabel='Month-Year',ylabel='# of Complaints',legend=False)
post_covid_dates.plot(ax=axes[1], title='Post-Covids Complaints', xlabel='Month-Year',ylabel='# of Complaints',legend=False)
# Out:
# <AxesSubplot: title={'center': 'Post-Covids Complaints'}, xlabel='Month-Year', ylabel='# of Complaints'>

# %% [markdown]
# ##### Timelines do differ, looks like more complaints came earlier post covid- vs. pre covid.
# ##### End of timeline trend looks similar

# %% [markdown]
# #### 2. What are the top 5 industries in each period?

# %%
post_covid = complaints_post_covid['NATURE OF COMPLAINT/INQUIRY'].value_counts().head(10).to_frame()

# %%
pre_covid = complaints_pre_covid['NATURE OF COMPLAINT/INQUIRY'].value_counts().head(10).to_frame()

# %%
pre_covid
# Out:
#                                         NATURE OF COMPLAINT/INQUIRY
# Other - All                                                     408
# Quality of Life-Noise - Trade Waste                             126
# Service - All                                                   124
# Information - All                                                96
# Misinformation - All                                             84
# Unlicensed Carter - Trade Waste                                  84
# Licensing - All                                                  67
# Quality of Life-Spillage - Trade Waste                           65
# Unsafe Driving - Trade Waste                                     56
# Containers-Unremoved - Trade Waste                               51

# %%
post_covid
# Out:
#                                         NATURE OF COMPLAINT/INQUIRY
# Other - All                                                     348
# Service - All                                                   121
# Licensing - All                                                 109
# Quality of Life-Noise - Trade Waste                              63
# Unlicensed Carter - Trade Waste                                  63
# Information - All                                                40
# Quality of Life-Spillage - Trade Waste                           32
# Containers-Unremoved - Trade Waste                               31
# Misinformation - All                                             27
# Unsafe Driving - Trade Waste                                     26

# %%
complaint_nature = pd.merge(pre_covid, post_covid, left_index =True, right_index= True)
complaint_nature.columns = ['Pre-Covid Complaints (3/2017-11/2019)','Post-Covid Complaints (3/2020-11/2022)']

# %%
complaint_nature
# Out:
#                                         Pre-Covid Complaints (3/2017-11/2019)  \
# Other - All                                                               408
# Quality of Life-Noise - Trade Waste                                       126
# Service - All                                                             124
# Information - All                                                          96
# Misinformation - All                                                       84
# Unlicensed Carter - Trade Waste                                            84
# Licensing - All                                                            67
# Quality of Life-Spillage - Trade Waste                                     65
# Unsafe Driving - Trade Waste                                               56
# Containers-Unremoved - Trade Waste                                         51
#
#                                         Post-Covid Complaints (3/2020-11/2022)
# Other - All                                                                348
# Quality of Life-Noise - Trade Waste                                         63
# Service - All                                                              121
# Information - All                                                           40
# Misinformation - All                                                        27
# Unlicensed Carter - Trade Waste                                             63
# Licensing - All                                                            109
# Quality of Life-Spillage - Trade Waste                                      32
# Unsafe Driving - Trade Waste                                                26
# Containers-Unremoved - Trade Waste                                          31

# %%
#Plot Bar
complaint_nature.plot.bar(colormap='Accent',figsize =(10,9),rot=85)
plt.xlabel("Nature of Complaint")
plt.ylabel("# of Complaints")
plt.title("Nature of Complaints pre and post covid time periods")
plt.tight_layout()
plt.xticks()
plt.show()

# %% [markdown]
# #### Proportianately outside of service and liscensing the decreases per nature are stable. Misinformation is one that is significantly less pre and post covid.

# %% [markdown]
# #### 3. What is the geographic distribution of complaints by city?¶

# %%
len(complaints_pre_covid)
# Out:
# 1535

# %%
len(complaints_post_covid)
# Out:
# 1108

# %%
fig, axes = plt.subplots(nrows=2, ncols=1,figsize =(10,10))
plt.subplots_adjust(wspace=1, hspace=.5)
complaints_pre_covid['COMPLAINT/INQUIRY CITY'].value_counts().head(6).plot.bar(ax=axes[0],rot=50,title ="Pre-Covid Complaints (3/2017-11/2019) top 6 cities",xlabel='City',ylabel='# of Complaints',ylim =(0,200))
complaints_post_covid['COMPLAINT/INQUIRY CITY'].value_counts().head(6).plot.bar(ax=axes[1],rot=50,title ="Post-Covid Complaints (3/2020-11/2022) top 6 cities",xlabel='City',ylabel='# of Complaints',ylim =(0,200))
# Out:
# <AxesSubplot: title={'center': 'Post-Covid Complaints (3/2020-11/2022) top 6 cities'}, xlabel='City', ylabel='# of Complaints'>

# %% [markdown]
# #### Overall volume of complaints is less "post-covid", Brooklyn, New York, Bronx, Queens, and Manhattan remain stable with slight changes - including the sixth borough shows an interesting insight as Queens is close to the bronx in the post covid peroid with similar overall volume from precovid

# %% [markdown]
# ### Learnings from this Pre-Covid and Post-Covid analysis are the following
# #### 1. Overall Complaint volume has decreased (By close to 400) in the same time period from 2017-2019,and 2020-2022 - This could be correlated to lower business during peak pandemic months but is not proven
# ####  2. From the timeline graph the spike changes from Jan of the second year (2019), to May 2021 - There is also more early activity in the  post pandemic months which is unexpected. Things from each time peroid at the end are similar
# #### 3. With Complaint volume being less, the city graph remains conistent with a slight variation in outer boroughs (Flushing, Queens) in who makes up the top 6 # of complaints.
#
# #### Next Steps: A geographical representation with a mapping element for number 3 is an enhancement I would like to explore with this graph, This could show the decline or incline of complaints in certain neighborhoods or geogrophies that may have been impacted by the pandemic
